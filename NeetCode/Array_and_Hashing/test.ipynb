# %%
l = sorted('afsa')

# %%
l.append('a')

# %%
result = {}
result.keys()
# Out:
# dict_keys([])

# %%
board = [["1","2",".",".","3",".",".",".","."],
 ["4",".",".","5",".",".",".",".","."],
 [".","9","8",".",".",".",".",".","3"],
 ["5",".",".",".","6",".",".",".","4"],
 [".",".",".","8",".","3",".",".","5"],
 ["7",".",".",".","2",".",".",".","6"],
 [".",".",".",".",".",".","2",".","."],
 [".",".",".","4","1","9",".",".","8"],
 [".",".",".",".","8",".",".","7","9"]]

# %%
[b[:3] for b in board[:3]]
# Out:
# [['1', '2', '.'], ['4', '.', '.'], ['.', '9', '8']]

# %%
tmp = [b[3:6] for b in board[3:6]]

# %%
import numpy as np

# %%
np.array(board)[:][0]
# Out:
# array(['1', '2', '.', '.', '3', '.', '.', '.', '.'], dtype='<U1')

# %%
board
# Out:
# [['1', '2', '.', '.', '3', '.', '.', '.', '.'],
#  ['4', '.', '.', '5', '.', '.', '.', '.', '.'],
#  ['.', '9', '8', '.', '.', '.', '.', '.', '3'],
#  ['5', '.', '.', '.', '6', '.', '.', '.', '4'],
#  ['.', '.', '.', '8', '.', '3', '.', '.', '5'],
#  ['7', '.', '.', '.', '2', '.', '.', '.', '6'],
#  ['.', '.', '.', '.', '.', '.', '2', '.', '.'],
#  ['.', '.', '.', '4', '1', '9', '.', '.', '8'],
#  ['.', '.', '.', '.', '8', '.', '.', '7', '9']]

# %%
[b[0] for b in board]
# Out:
# ['1', '4', '.', '5', '.', '7', '.', '.', '.']

# %%
from collections import Counter

# %%
cnt = Counter([t for tt in tmp for t in tt if t != '.']).values()

# %%
for c in cnt:
    if c > 1:
        False

# %%
s="Was it a car or a cat I saw?"

import re

s = s.lower()
s = re.sub('[^a-z]','', s)
s
# Out:
# 'wasitacaroracatisaw'
